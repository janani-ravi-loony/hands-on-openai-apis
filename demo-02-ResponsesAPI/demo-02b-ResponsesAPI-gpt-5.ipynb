# %%
from openai import OpenAI
import pandas as pd
from IPython.display import display

import os

# %%
os.environ["OPENAI_API_KEY"] = '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'

# %%
client = OpenAI()

client

# %% [markdown]
# API reference:
# https://platform.openai.com/docs/api-reference/responses/create
#
# Text generation:
# https://platform.openai.com/docs/guides/text?api-mode=responses&lang=python

# %% [markdown]
# ### Verbosity

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

response
# Out:
# Response(id='resp_68b02679a29881a383bc35bfc46aad9b0097b55253657dbe', created_at=1756374649.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-mini-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_68b0267a76ac81a3b56da07858bf3c8b0097b55253657dbe', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_68b0267c6e0081a3ad7d51e0cf92e4b90097b55253657dbe', content=[ResponseOutputText(annotations=[], text='Keys click like raindrops composing a tune,\nLogic unfurls, a map of midnight light.\nError messages vanish, solved by noon—\ntiny triumphs turn the dark to bright.\n\nVariables dance, functions spin their threads,\nloops hum a rhythm, memory holds the song.\nEach bug a mystery that clears our heads,\neach build a castle where ideas belong.\n\nInfinite playground of rule and art,\nsyntax and whim fuse into one plan.\nA single keystroke sparks a beating heart—\nwe shape the world 
# ...

# %%
print(response.output[1].content[0].text)
# Out:
# Keys click like raindrops composing a tune,
# Logic unfurls, a map of midnight light.
# Error messages vanish, solved by noon—
# tiny triumphs turn the dark to bright.
#
# Variables dance, functions spin their threads,
# loops hum a rhythm, memory holds the song.
# Each bug a mystery that clears our heads,
# each build a castle where ideas belong.
#
# Infinite playground of rule and art,
# syntax and whim fuse into one plan.
# A single keystroke sparks a beating heart—
# we shape the world with code, and laugh at what we can.
#
# Joy lives in the challenge, the schematic run:
# every solved puzzle whispers—programming is fun.

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'medium'}
)

print(response.output[1].content[0].text)
# Out:
# Keys click like rain on a bright tin roof,
# each bracket a doorway, each semicolon a pause.
# I carve logic out of questions and coffee,
# watching ideas condense into glass-clear functions.
#
# Loops are lullabies, recursion a friendly echo,
# variables whisper names that hold tiny universes.
# Errors are maps with red pins—annoying, yes—
# but each fix is a small triumphant cartwheel.
#
# I sculpt with syntax, stack dreams into arrays,
# pipe light through ifs and whens until features glow.
# Tests breathe confidence; commits are little time capsules
# that say: I tried, I built, I learned.
#
# In the hush of late night, the program sings,
# a chorus of clean output and satisfied compilers.
# There’s a kind of joy in making machines obey art—
# programming is play where thought becomes tool and wonder.

# %% [markdown]
# An easy way to specify instructions in the responses API

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output[1].content[0].text)
# Out:
# Byte by byte I build a world,
# a small bright city of my own —
# looping streets of logic curled,
# variables like bricks are thrown.
# I plant a seed of a single line,
# watch functions bloom and promises keep;
# a semicolon finishes a sign,
# and silent engines wake from sleep.
#
# There’s music in a cursor’s blink,
# rhythms in the tapping keys;
# an if that teaches me to think,
# a for that folds the nights with ease.
# Errors are riddles wrapped in light —
# a bug is just a secret map —
# I chase its clue from left to right,
# and laugh when finally it snaps.
#
# I love the quiet algebra
# that makes a thought become a thing:
# an array of possibilities,
# a loop that lets my ideas sing.
# Recursion like a mirror song,
# stack frames climbing to the sky —
# each call returns the code’s sweet throng,
# and solutions echo back, reply.
#
# In coffee steam and late-night glow,
# collaborators on a screen:
# we push, we merge, we watch it grow,
# we fix the parts no eye had seen.
# ...

# %% [markdown]
# Verbosity also affects the length and complexity of the generated code

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings."
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

print(response.output[1].content[0].text)
# Out:
# Idea: compare numeric values by (number of significant digits, lexicographic order of the significant digits). Treat a string of only zeros as "0". This avoids converting to bigints.
#
# Python (simple, clear; builds normalized keys):
# ```
# def sort_numeric_strings(arr):
#     def sig(s):
#         t = s.lstrip('0')
#         return t if t != '' else '0'
#     return sorted(arr, key=lambda s: (len(sig(s)), sig(s)))
# ```
#
# Notes:
# - Stable and handles leading zeros (e.g. "001" -> value 1).
# - Time: O(N log N * M) where M is average cost to compare keys (length + lexicographic).
# - Memory: normalized strings are created for keys; for extreme sizes this may be too memory-heavy.
#
# C++ (scales better: avoids allocating normalized copies during comparisons):
# ```
# #include <algorithm>
# #include <string>
# #include <vector>
#
# static inline size_t first_non_zero(const std::string &s) {
#     size_t i = 0, n = s.size();
#     while (i < n && s[i] == '0') ++i;
#     return i;
# ...

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings."
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output[1].content[0].text)
# Out:
# Below is a robust, memory- and comparison-efficient method (with production-ready Python code) to sort an array of decimal strings by numeric value. It handles:
#
# - Very large integers (millions of digits) without parsing to Python integers.
# - Leading zeros (treats "001" and "1" as equal numeric values).
# - Large arrays (up to 1e6 strings) — the algorithm avoids copying whole big strings whenever possible.
# - Stable ordering for strings that represent the same numeric value (original relative order preserved).
#
# High-level idea
# - For each string s, find the index of the first non-zero digit; the numeric value is represented by the substring s[first_non_zero:] (or "0" if the string is all zeros).
# - Two numbers compare by (normalized length, lexicographic order of the normalized substring).
# - Group strings by normalized length (count-sort by length).
# ...

# %% [markdown]
# ### Reasoning

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "minimal"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output[1].content[0].text)
# Out:
# One standard solution (F = farmer; W = wolf; G = goat; C = cabbage; R = right bank — assume all start on left bank):
#
# 1. Farmer takes the goat across to the right bank. (Left: wolf, cabbage. Right: goat)
# 2. Farmer returns alone to the left bank. (Left: wolf, cabbage. Right: goat)
# 3. Farmer takes the wolf across to the right bank. (Left: cabbage. Right: wolf, goat)
# 4. Farmer brings the goat back to the left bank. (Left: goat, cabbage. Right: wolf)
# 5. Farmer takes the cabbage across to the right bank. (Left: goat. Right: wolf, cabbage)
# 6. Farmer returns alone to the left bank. (Left: goat. Right: wolf, cabbage)
# 7. Farmer takes the goat across to the right bank. (Left: --. Right: wolf, goat, cabbage)
#
# All three are now safely on the far bank.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "medium"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output[1].content[0].text)
# Out:
# Number the riverbanks "Left" (start) and "Right" (destination). Initially: Left = {Farmer, Wolf, Goat, Cabbage}, Right = {}.
#
# Sequence (7 crossings):
#
# 1. Farmer takes Goat to Right.
#    Left = {Wolf, Cabbage}; Right = {Goat, Farmer}
#
# 2. Farmer returns alone to Left.
#    Left = {Wolf, Cabbage, Farmer}; Right = {Goat}
#
# 3. Farmer takes Wolf to Right.
#    Left = {Cabbage}; Right = {Wolf, Goat, Farmer}
#
# 4. Farmer brings Goat back to Left.
#    Left = {Goat, Cabbage, Farmer}; Right = {Wolf}
#
# 5. Farmer takes Cabbage to Right.
#    Left = {Goat}; Right = {Wolf, Cabbage, Farmer}
#
# 6. Farmer returns alone to Left.
#    Left = {Goat, Farmer}; Right = {Wolf, Cabbage}
#
# 7. Farmer takes Goat to Right.
#    Left = {}; Right = {Wolf, Goat, Cabbage, Farmer}
#
# No step ever leaves Wolf alone with Goat or Goat alone with Cabbage, so all arrive safely.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "high"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output[1].content[0].text)
# Out:
# One correct sequence (7 one-way crossings) is:
#
# Start: Left = Farmer, Wolf, Goat, Cabbage | Right = —
#
# 1. Farmer takes Goat to the right.
#    Left = Wolf, Cabbage | Right = Farmer, Goat
# 2. Farmer returns alone to the left.
#    Left = Farmer, Wolf, Cabbage | Right = Goat
# 3. Farmer takes Wolf to the right.
#    Left = Cabbage | Right = Farmer, Wolf, Goat
# 4. Farmer brings Goat back to the left.
#    Left = Farmer, Goat, Cabbage | Right = Wolf
# 5. Farmer takes Cabbage to the right.
#    Left = Goat | Right = Farmer, Wolf, Cabbage
# 6. Farmer returns alone to the left.
#    Left = Farmer, Goat | Right = Wolf, Cabbage
# 7. Farmer takes Goat to the right.
#    Left = — | Right = Farmer, Wolf, Goat, Cabbage
#
# At no time are the Wolf and Goat or the Goat and Cabbage left alone together without the Farmer, so everything arrives safely.

# %%
response = client.responses.create(
    model="gpt-5-mini",
    input="""
    Please use the code_exec tool to calculate the total number of unique vowels (a, e, i, o, u) in 
    the phrase "supercalifragilisticexpialidocious", then compute the factorial of that count.
    """,
    text={"format": {"type": "text"}},
    tools=[
        {
            "type": "custom",
            "name": "code_exec",
            "description": "Executes arbitrary python code",
        }
    ]
)
# Out:
# ResponseReasoningItem(id='rs_68b02b17f990819dbb3f87132ffd0bb70a42b420d98d7e73', summary=[], type='reasoning', content=None, encrypted_content=None, status=None)

# %%
print(response.output[1])
# Out:
# ResponseCustomToolCall(call_id='call_XrYXoql95IPUBqJzvLWryuCl', input='# Counting unique vowels in the given phrase and computing factorial of the count\ntext = "supercalifragilisticexpialidocious"\nvowels = set("aeiou")\nunique_vowels = sorted(list(vowels.intersection(set(text))))\ncount = len(unique_vowels)\n\nimport math\nfactorial_of_count = math.factorial(count)\n\n{\n    "text": text,\n    "unique_vowels": unique_vowels,\n    "count": count,\n    "factorial": factorial_of_count\n}', name='code_exec', type='custom_tool_call', id='ctc_68b02b1bff28819d9d429e820f832fb30a42b420d98d7e73', status='completed')

# %%
tool_call = response.output[1] if len(response.output) > 1 else None

if tool_call and tool_call.type == "custom_tool_call":
    print("--- tool name ---")
    print(tool_call.name)
    print("--- tool call argument (generated code) ---")
    print(tool_call.input)
# Out:
# --- tool name ---
# code_exec
# --- tool call argument (generated code) ---
# # Counting unique vowels in the given phrase and computing factorial of the count
# text = "supercalifragilisticexpialidocious"
# vowels = set("aeiou")
# unique_vowels = sorted(list(vowels.intersection(set(text))))
# count = len(unique_vowels)
#
# import math
# factorial_of_count = math.factorial(count)
#
# {
#     "text": text,
#     "unique_vowels": unique_vowels,
#     "count": count,
#     "factorial": factorial_of_count
# }
