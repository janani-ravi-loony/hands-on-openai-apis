# %%
from openai import OpenAI

import os

# %%
os.environ["OPENAI_API_KEY"] = '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'

# %%
client = OpenAI()

client

# %% [markdown]
# API reference:
# https://platform.openai.com/docs/api-reference/responses/create
#
# Text generation:
# https://platform.openai.com/docs/guides/text?api-mode=responses&lang=python

# %% [markdown]
# ### Verbosity

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

response
# Out:
# Response(id='resp_011cee72433022be006a21844933ec819db8d767d24e669dea', created_at=1780581449.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-mini-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_011cee72433022be006a218449f5d4819d8507eae5888ee7fe', summary=[], type='reasoning', content=[], encrypted_content=None, status=None), ResponseOutputMessage(id='msg_011cee72433022be006a21844c3b58819d8918e772f0a59395', content=[ResponseOutputText(annotations=[], text='Keys click like percussion; logic sings.\nI sketch with symbols, build with tiny things—\na semicolon bridges thought to action,\nfunctions fold ideas into satisfaction.\n\nBugs are riddles tucked in midnight light,\neach breakpoint a flash of sudden sight.\nLoops become dances, recursion a song,\nand algorithms hum as I move along.\n\nWhen tests pass green, the screen feels bright as sun;\ndeployments pop like confetti—job well done.\nStacked lines become worlds I shape and run:\noh, programming—so strange and so much fun.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1780581453.0, conversation=None, max_output_tokens=None, max_tool_calls=None, moderation=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention='in_memory', reasoning=Reasoning(effort='medium', generate_summary=None, summary=None, context='current_turn'), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='low'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=302, output_tokens_details=OutputTokensDetails(reasoning_tokens=128), total_tokens=318), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)

# %%
print(response.output_text)
# Out:
# Keys click like percussion; logic sings.
# I sketch with symbols, build with tiny things—
# a semicolon bridges thought to action,
# functions fold ideas into satisfaction.
#
# Bugs are riddles tucked in midnight light,
# each breakpoint a flash of sudden sight.
# Loops become dances, recursion a song,
# and algorithms hum as I move along.
#
# When tests pass green, the screen feels bright as sun;
# deployments pop like confetti—job well done.
# Stacked lines become worlds I shape and run:
# oh, programming—so strange and so much fun.

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'medium'}
)

print(response.output_text)
# Out:
# Tap-tap—ideas become architecture,
# brackets hug logic like scaffolding,
# variables hum with possibility.
# A blank editor is not emptiness but invitation:
# the cursor a tiny compass,
# pointing where imagination meets instruction.
#
# I write a function and watch a world appear —
# loops like heartbeats, recursion like echoing thoughts,
# conditions that sift chaos into meaning.
# Bugs are curious chaperones, coaxing me closer,
# each fix a small triumph, the soft glow of tests passing
# like applause in a midnight theater.
#
# Stack traces map the adventure,
# algorithms sing in tidy complexity,
# and every refactor is a polishing of intent.
# We shape invisible things that do visible work:
# light switches in apps, ladders for users to climb,
# maps that turn questions into answers.
#
# Pairs at the screen, terminals aglow,
# commits like postcards sent from the frontier.
# There’s coffee and music and the quiet of focus,
# that delicious hush when the world narrows to a problem
# and the solution arrives—unexpected, elegant.
# Programming is play, problem, poem, and power;
#
# so much fun is tucked between semicolons and sparks,
# where curiosity writes the code and joy debugs the day.

# %% [markdown]
# An easy way to specify instructions in the responses API

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output_text)
# Out:
# The cursor blinks — a tiny metronome,
# counting out the heartbeat of a new idea.
# Keys click like rain on a tin roof,
# and the night bends low to listen.
#
# I string logic like lanterns along a dark trail,
# each function a step, each loop a lantern's glow.
# Variables become characters in a play I script,
# algorithms choreographing elegant moves.
# A bug is not an enemy but a secret door:
# I pry it open with curiosity and coffee,
# follow the twist of a wrong assumption
# until the room of truth appears, bright with possibility.
#
# Compilers hum an approving tune;
# tests tap their tiny cymbals. Green lights wink.
# I save the world in tidy commits — a trail of small triumphs,
# each push a paper airplane launched across the network,
# each merge a chorus arriving in harmony.
#
# There is a thrill in folding complexity into a single line,
# in watching patterns click together like gears,
# in the instant joy when abstract becomes real:
# the empty console sings, then prints, then laughs.
# I am an architect of invisible rooms,
# a composer of instructions that make machines dream.
# Stack traces read like treasure maps;
# Stack Overflow answers are friendly signposts.
#
# And oh the first program — "Hello, World!" —
# a shy handshake with a vast, kind universe.
# Later, I build gardens of data and bridges of APIs,
# machines that learn and worlds that simulate summer.
# I refactor not because it must be done,
# but because beauty can be trimmed and made to sing.
#
# Programming is play with rules that reward playfulness,
# a long puzzle where every solved piece is a small festival.
# We work in midnight guilds and morning standups,
# we share snippets like recipes for new flavors of wonder.
# It is problem and poem, hammer and harp,
# logic braided with imagination until it hums.
#
# So give me my keyboard and a quiet corner,
# some music in the headphones and a stubborn idea.
# I will carve an entire universe from syntax and will,
# and when it runs — when the console lights up —
# I'll grin like a child who just found the biggest secret:
# that making things work can feel like magic, every time.

# %% [markdown]
# Verbosity also affects the length and complexity of the generated code

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings.
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

print(response.output_text)
# Out:
# Here's a concise Python solution that sorts the strings by numeric value (handles leading zeros and very large numbers):
#
# ```python
# def sort_numeric_strings(arr):
#     # normalize each string to remove leading zeros (treat "" as "0")
#     norms = [s.lstrip('0') or '0' for s in arr]
#     # sort by (numeric length, numeric lexicographic) and return original strings in that order
#     return [orig for _, orig in sorted(zip(norms, arr), key=lambda t: (len(t[0]), t[0]))]
# ```
#
# Usage: call sort_numeric_strings(your_list). Complexity: O(total_digits + N log N * avg_compare_cost). For extremely memory- or time-constrained cases, a custom comparator or bucketing by digit-length can be used to reduce temporary-string allocations.

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings."
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output_text)
# Out:
# Short answer / rule of thumb
# - Numeric order for non-negative integers represented as decimal strings is: first by length (number of digits) and, when lengths are equal, by lexicographic order.
# - So to sort them you can group by length (after removing leading zeros), then sort each group lexicographically and concatenate groups from smallest length to largest.
#
# Important details
# - Leading zeros: "0012" and "12" are the same integer. You should normally strip leading zeros (treat "000" as "0") before deciding the length. Decide whether you must preserve the original textual form in the output (see code options below).
# - Memory / scale: If the whole dataset fits in RAM, an in-memory bucket-by-length approach is simple and fast. If the entire dataset (or individual numbers) doesn't fit in memory, you must use an external (disk-based) sort: read chunks, sort each chunk, write sorted runs to disk and then k-way-merge them.
#
# Example Python implementations
# 1) In-memory sort (handles up to whatever your RAM allows). This is efficient and avoids unnecessary full-string comparisons across numbers with different lengths.
#
# - Behavior: by default returns normalized canonical strings (no leading zeros, "0" for zero). Optionally you can keep the original string formatting while sorting by numeric value.
#
# ```python
# def sort_numeric_strings_in_memory(arr, keep_original=False):
#     """
#     Sort a list of decimal non-negative integer strings by numeric value.
#
#     Arguments:
#       arr: iterable/list of strings representing non-negative integers (may have leading zeros).
#       keep_original: if False (default) the returned strings are normalized (no leading zeros,
#                      "0" for zero). If True, original strings are returned but sorted by numeric value.
#
#     Returns:
#       A list of strings sorted by numeric value (normalized or original depending on keep_original).
#     """
#     from collections import defaultdict
#
#     # Bucket by normalized length
#     buckets = defaultdict(list)  # length -> list of (normalized_str, original_str)
#     for s in arr:
#         if not s:  # treat empty as "0" if you want; adjust if empty isn't valid input
#             t = "0"
#         else:
#             # strip leading zeros; if all zeros, keep a single "0"
#             t = s.lstrip('0') or "0"
#         buckets[len(t)].append((t, s))
#
#     # Iterate lengths in ascending order, sort each bucket lexicographically by normalized string
#     result = []
#     for length in sorted(buckets.keys()):
#         bucket = buckets[length]
#         # Sort only by normalized string; Python sort is stable so original order among equal keys is preserved
#         bucket.sort(key=lambda pair: pair[0])
#         if keep_original:
#             result.extend(pair[1] for pair in bucket)
#         else:
#             result.extend(pair[0] for pair in bucket)
#
#     return result
# ```
#
# Example:
# - Input: ["10", "2", "001", "0", "0000", "123", "12"]
# - sort_numeric_strings_in_memory(..., keep_original=False) returns ["0","0","1","2","10","12","123"]
# - sort_numeric_strings_in_memory(..., keep_original=True) returns ["0","0000","001","2","10","12","123"] (numeric order but original forms kept; ties preserve input order among identical numeric values because sort is stable).
#
# Complexity (in-memory)
# - Time: dominated by sorting within buckets. If N is number of strings and D_total is total number of digits across all strings, expected time is roughly O(sum_k m_k log m_k * C_compare) where C_compare is cost of comparing equal-length strings (lexicographic). Comparisons for equal-length strings can cost up to O(length), so worst-case could approach O(D_total log N) in pathological inputs, but typically faster.
# - Space: O(N) pointers plus the storage for strings (which you already have). No extra copies of the full strings are made.
#
# 2) External (disk-based) sort for data that doesn't fit in RAM
# If the input is too large to hold in memory (for example, many very long numbers), use an external merge sort. Outline:
#
# - Phase 1: Read as many strings as fit in memory (a chunk). For each string in the chunk, normalize (strip leading zeros) and group by length; sort each bucket lexicographically and then write a sorted run to disk (one run file per chunk). Write each line as either the normalized string (if you don't need original formatting) or as a small serialized record with both normalized and original (e.g., tab-separated "normalized\toriginal\n").
# - Phase 2: K-way merge the sorted run files. Use a min-heap keyed by (length, normalized_string). Open each run file and read its first line (normalized string). Push (length, normalized_string, run_id, original_if_needed) onto the heap. Pop smallest, write to output and read next line from that run. Continue until heap empty.
#
# This merges sorted runs in O(total_size * log(Number_of_runs)) disk I/O passes.
#
# Sketch (very high-level) of chunk writer and merge using heapq:
# - Use fixed memory budget (e.g., 512MB). Read strings until you approach the budget, sort as above, write run to temp file.
# - Use heapq to merge runs; compare first by length (int) then lexicographically by the normalized_string (which is safe because runs are already sorted by that key).
#
# Practical notes / pitfalls
# - Avoid using a key function that returns (len(s), s) on each call if you expect huge numbers of very long strings and tight memory constraints: Python's sort will call the key function once per element and keep the key objects in memory; that is normally fine, but for huge inputs the bucket approach is more transparent and usually lighter-weight.
# - If you must keep original textual formatting: keep a small extra reference to the original string in the buckets or on disk. You don't need to duplicate full strings to perform the comparison—just store references.
# - If many numbers have equal length and are equal on long prefixes, comparisons can be expensive. External radix-style approaches that sort by leading blocks (e.g., 64-bit chunks or prefixes) may help in some situations, but are more complex to implement reliably.
# - Validate input: empty strings or non-digit characters should be handled or rejected according to your needs.
#
# If you want, I can:
# - Provide a full external-sort Python script (with chunking, temp files and k-way merge).
# - Provide a memory-optimized in-memory implementation variant (for example one that uses arrays of indices to preserve original strings rather than storing pairs).
# - Help you choose parameters (chunk size, temp dir, concurrency) for a real dataset given available RAM and disk speed.
#
# Which variant would you like (simple in-memory code, normalized vs original output, or a full external-sort implementation)?

# %% [markdown]
# ### Reasoning

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "minimal"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# One solution (the standard one) is:
#
# 1. Farmer takes the goat across the river. (Left: wolf, cabbage. Right: goat.)
# 2. Farmer returns alone to the left bank. (Left: wolf, cabbage. Right: goat.)
# 3. Farmer takes the wolf across. (Left: cabbage. Right: wolf, goat.)
# 4. Farmer brings the goat back to the left bank. (Left: goat, cabbage. Right: wolf.)
# 5. Farmer takes the cabbage across. (Left: goat. Right: wolf, cabbage.)
# 6. Farmer returns alone to the left bank. (Left: goat. Right: wolf, cabbage.)
# 7. Farmer takes the goat across. (Left: —. Right: wolf, goat, cabbage.)
#
# All three are now safely across.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "medium"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# Label the starting bank "Left" and the far bank "Right". Initial: Left = {Farmer, Wolf, Goat, Cabbage}, Right = {}.
#
# 1. Farmer takes the Goat to Right.
#    Left = {Wolf, Cabbage}, Right = {Farmer, Goat}
# 2. Farmer returns alone to Left.
#    Left = {Farmer, Wolf, Cabbage}, Right = {Goat}
# 3. Farmer takes the Wolf to Right.
#    Left = {Cabbage}, Right = {Farmer, Wolf, Goat}
# 4. Farmer brings the Goat back to Left.
#    Left = {Farmer, Goat, Cabbage}, Right = {Wolf}
# 5. Farmer takes the Cabbage to Right.
#    Left = {Goat}, Right = {Farmer, Wolf, Cabbage}
# 6. Farmer returns alone to Left.
#    Left = {Farmer, Goat}, Right = {Wolf, Cabbage}
# 7. Farmer takes the Goat to Right.
#    Left = {}, Right = {Farmer, Wolf, Goat, Cabbage}
#
# All are safely across; at no time were Wolf and Goat or Goat and Cabbage left alone together.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "high"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# 1. Farmer takes the goat across.
#    Left: Wolf, Cabbage. Right: Farmer, Goat.
#
# 2. Farmer returns alone.
#    Left: Farmer, Wolf, Cabbage. Right: Goat.
#
# 3. Farmer takes the wolf across.
#    Left: Cabbage. Right: Farmer, Wolf, Goat.
#
# 4. Farmer brings the goat back.
#    Left: Farmer, Goat, Cabbage. Right: Wolf.
#
# 5. Farmer takes the cabbage across.
#    Left: Goat. Right: Farmer, Wolf, Cabbage.
#
# 6. Farmer returns alone.
#    Left: Farmer, Goat. Right: Wolf, Cabbage.
#
# 7. Farmer takes the goat across.
#    Left: —. Right: Farmer, Wolf, Goat, Cabbage.
#
# No dangerous pair (wolf+goat or goat+cabbage) is ever left alone, so everything arrives safely.

# %%
response = client.responses.create(
    model="gpt-5-mini",
    input="""
    Please use the code_exec tool to calculate the total number of unique vowels (a, e, i, o, u) in 
    the phrase "supercalifragilisticexpialidocious", then compute the factorial of that count.
    """,
    text={"format": {"type": "text"}},
    tools=[
        {
            "type": "custom",
            "name": "code_exec",
            "description": "Executes arbitrary python code",
        }
    ]
)

# %%
print(response.output[1])
# Out:
# ResponseCustomToolCall(call_id='call_yl8TrVvxIryWFNAQtgj4oZB0', input='# Python code to compute unique vowels and factorial\nphrase = "supercalifragilisticexpialidocious"\nvowels = set([c for c in phrase if c in \'aeiou\'])\ncount = len(vowels)\nimport math\nfact = math.factorial(count)\n{"phrase": phrase, "unique_vowels": sorted(list(vowels)), "count": count, "factorial": fact}', name='code_exec', type='custom_tool_call', id='ctc_0b2b74ff9c76d8d7006a2184c444cc81a3915053e071aecb1e', namespace=None, status='completed')

# %%
tool_call = response.output[1] if len(response.output) > 1 else None

if tool_call and tool_call.type == "custom_tool_call":
    print("--- tool name ---")
    print(tool_call.name)
    print("--- tool call argument (generated code) ---")
    print(tool_call.input)
# Out:
# --- tool name ---
# code_exec
# --- tool call argument (generated code) ---
# # Python code to compute unique vowels and factorial
# phrase = "supercalifragilisticexpialidocious"
# vowels = set([c for c in phrase if c in 'aeiou'])
# count = len(vowels)
# import math
# fact = math.factorial(count)
# {"phrase": phrase, "unique_vowels": sorted(list(vowels)), "count": count, "factorial": fact}
