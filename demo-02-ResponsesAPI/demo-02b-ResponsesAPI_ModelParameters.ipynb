# %%
from openai import OpenAI

import os

# %%
os.environ["OPENAI_API_KEY"] = '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'

# %%
client = OpenAI()

client

# %% [markdown]
# API reference:
# https://platform.openai.com/docs/api-reference/responses/create
#
# Text generation:
# https://platform.openai.com/docs/guides/text?api-mode=responses&lang=python

# %% [markdown]
# ### Verbosity

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

response
# Out:
# Response(id='resp_0d49728702a2e1f000693aaf2501348190addd4436185c32be', created_at=1765453605.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-mini-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0d49728702a2e1f000693aaf25d620819086a482e85aebd5d9', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_0d49728702a2e1f000693aaf277d0c8190a04d07857f6a9b61', content=[ResponseOutputText(annotations=[], text='Keys click like rain on a bright afternoon,\nlogic unfolding into motion and tune.\nA blank file is a universe waiting to start,\neach function a doorway, each loop a new art.\n\nVariables hum with possibility,\nerrors flirt like riddles that beg for agility.\nI chase bugs like shadows until they unwind,\nthen watch tiny triumphs bloom in my mind.\n\nStacks stack like stories, threads weave a song,\nalgorithms dancing, exact and strong.\nCompile, run — the world rearranges,\none line of code and the future changes.\n\nJoy is the spark where ideas become done;\nnothing else sings like programming fun.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='low'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=16, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=193, output_tokens_details=OutputTokensDetails(reasoning_tokens=64), total_tokens=209), user=None, billing={'payer': 'developer'}, store=True)

# %%
print(response.output_text)
# Out:
# Keys click like rain on a bright afternoon,
# logic unfolding into motion and tune.
# A blank file is a universe waiting to start,
# each function a doorway, each loop a new art.
#
# Variables hum with possibility,
# errors flirt like riddles that beg for agility.
# I chase bugs like shadows until they unwind,
# then watch tiny triumphs bloom in my mind.
#
# Stacks stack like stories, threads weave a song,
# algorithms dancing, exact and strong.
# Compile, run — the world rearranges,
# one line of code and the future changes.
#
# Joy is the spark where ideas become done;
# nothing else sings like programming fun.

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'medium'}
)

print(response.output_text)
# Out:
# Keys click like castanets in a midnight room,
# lines of thought folding into light.
# I sculpt with logic—if, loop, and bloom—
# and watch a shy idea take flight.
#
# A stack of tiny miracles arrange,
# functions whispering secrets back and forth.
# Errors are riddles I love to exchange,
# each bug a map that guides me north.
#
# The terminal glows like a campfire bright,
# REPL feedback, a friendly echo.
# Build, run, deploy — the thrill of sight
# when something strange becomes my staccato.
#
# Patterns hum; algorithms swing and sway,
# data rivers braided by intention.
# Comfort in chaos, joy in the fray —
# crafting order from abstract invention.
#
# From first "hello" to production's hum,
# every push, each test, each version spun,
# programming sings: it's endlessly fun—
# a playground where ideas become.

# %% [markdown]
# An easy way to specify instructions in the responses API

# %%
question = "Write a poem about how programming is so much fun"

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output_text)
# Out:
# The keyboard is a castanet, a rain of tiny notes,
# each keystroke a pebble thrown into an endless pond.
# I write a spark of instruction — a little luminous rope —
# and watch it braid itself into a bridge across the void.
#
# There’s mischief in the stack, a secret in the loop:
# a puzzle folded inside a puzzle, waiting for the pry.
# Logic becomes a garden where conditions bloom like fruit,
# and recursive maps unfold like spirals of a seashell sky.
#
# Compile, and the machine takes a breath; run, and the world answers.
# A blank screen becomes a city, a function the flicker of a streetlight.
# Variables hum as street names, objects line up like storefronts,
# and I send them postcards of data until they start to sing.
#
# Debugging is detective work with coffee and a grin —
# tracing breadcrumbs of state through alleys of assumptions.
# Errors are riddles that blush and then reveal themselves,
# and every fixed bug is a small, delighted resurrection.
#
# There’s a rhythm in refactor, a choreography of thought,
# where messy rooms get swept into clever, logical closets.
# Version control is a time machine: I can rewind, compare, and share
# the small historic rebellions that made the present possible.
#
# Pairing is a duet: two minds compassing one bright problem,
# two screens like campfires where ideas take turns warming hands.
# Open-source is a market square, strangers trade perfect little tools,
# and suddenly the work is a chorus louder than I can sing alone.
#
# Sometimes it’s algebra, sometimes architecture — pure play,
# sometimes a quiet art: trimming rough edges till the interface shines.
# Sometimes it’s improvisation, a jazz riff in a branch,
# sometimes it’s craft: precise, patient, the joy of getting it right.
#
# And then the moment — a click, a blink, a green light’s calm approval —
# the program breathes and folds its wings and flies where once was blank.
# That tiny victory tastes like the first bite of something made:
# a thing that did not exist and now behaves like a promise kept.
#
# Programming is a playground where rules are clay and time is elastic,
# where curiosity is capital and mistakes are tuition.
# I build, I break, I learn, I laugh — the work is full of small delights —
# and every simple “hello world” feels like a private sun.
#
# So yes, it’s logic and syntax and late-night coffee runs,
# but deeper: it’s the joy of making invisible things move.
# Ask me why I keep coming back and I’ll just smile and say,
# because turning thought into action — that is so much fun.

# %% [markdown]
# Verbosity also affects the length and complexity of the generated code

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings.
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'low'}
)

print(response.output_text)
# Out:
# Solution idea (concise)
# - Compare numeric strings by their integer value: first by length after stripping leading zeros, then lexicographically for equal lengths.
# - Preserve original string forms in the output (so leading zeros remain if present).
# - For very large inputs you may need an external/merge sort; below are two Python variants: a simple key-based one (easy, fast for typical sizes) and a comparator-based one that avoids allocating trimmed copies (more memory-friendly for huge strings).
#
# Python — simple (easy, uses trimmed copies as sort keys)
# ```python
# def sort_numeric_strings(arr):
#     def norm(s):
#         t = s.lstrip('0')
#         return t if t != '' else '0'
#     return sorted(arr, key=lambda s: (len(norm(s)), norm(s)))
# ```
#
# Python — comparator (avoids allocating trimmed substrings; compares in-place)
# ```python
# import functools
#
# def sort_numeric_strings_cmp(arr):
#     def first_nonzero_index(s):
#         i = 0
#         n = len(s)
#         while i < n and s[i] == '0':
#             i += 1
#         return i if i < n else n - 1  # if all zeros, treat as single '0' digit at last char
#
#     def cmp(a, b):
#         ia, ib = first_nonzero_index(a), first_nonzero_index(b)
#         la, lb = len(a) - ia, len(b) - ib
#         if la != lb:
#             return la - lb
#         # same effective length: compare digit-by-digit without slicing
#         for k in range(la):
#             ca = a[ia + k]
#             cb = b[ib + k]
#             if ca != cb:
#                 return (1 if ca > cb else -1)
#         return 0
#
#     arr.sort(key=functools.cmp_to_key(cmp))
#     return arr
# ```
#
# Notes
# - Both return the sorted list of strings. For equal numeric values (e.g., "001" and "1"), ordering will be stable as returned by Python's sort.
# - For truly huge datasets (millions of strings up to millions of digits), use external/merge sort and store only comparison metadata in memory to avoid running out of RAM.

# %%
question = """
You're given an array of up to 1 million strings, where each string represents a non-negative integer. 
These integers can be extremely large, with up to 1 million digits each. Your task is to:

Sort this array in ascending numerical order, based on integer value—not lexicographically.

Return the sorted array as a list of strings."
"""

response = client.responses.create(
    model="gpt-5-mini",
    input=question,
    text={"verbosity": 'high'}
)

print(response.output_text)
# Out:
# Short answer / key idea
# - Compare integer values by (effective length, lexicographic order), where "effective" length ignores leading zeros (so "001" -> "1" has length 1).
# - So you can sort by the key (len(normalized_string), normalized_string).
# - For very large data, use a two-phase approach: bucket by normalized length, then for each bucket of equal length sort lexicographically (use radix/counting sort for best worst-case time).
#
# Below I give:
# 1) A simple, correct Python implementation (easy to read, fine for most inputs).
# 2) A more scalable approach using counting/radix sort within equal-length buckets (better worst-case time when lots of very long numbers).
# 3) Notes on complexity, memory, and what to do if the data are too large to fit in RAM (external sort).
#
# 1) Simple correct implementation (Python)
# - This is the usual practical solution. It strips leading zeros (treating an all-zero string as "0"), builds a key (length, normalized string), sorts by that key, and returns the original string representations in numeric order.
#
# Code:
#
# def sort_numeric_strings_simple(arr):
#     """
#     Sort list of decimal integer strings by numeric value and return sorted list of original strings.
#     Handles leading zeros by numeric normalization. Stable for values that compare equal.
#     """
#     normalized = []
#     for s in arr:
#         # normalize: remove leading zeros, but keep "0" if all zeros
#         nz = s.lstrip('0')
#         if nz == "":
#             nz = "0"
#         normalized.append((len(nz), nz, s))
#     # sort by (length of normalized, normalized lexicographically)
#     normalized.sort(key=lambda t: (t[0], t[1]))
#     return [orig for (_, _, orig) in normalized]
#
# Usage:
# sorted_list = sort_numeric_strings_simple(my_array)
#
# When to use this:
# - When the data fits comfortably in memory and you only have up to moderate numbers of very long strings.
# - Time complexity: O(n * L_avg * log n) for comparison-based sort, where L_avg is average significant-digit length after stripping leading zeros. For many long equal-length strings this can be expensive.
# - Memory: stores one small tuple per item plus the normalized string (a copy) — extra memory ~ O(n * L_avg) for normalization.
#
# 2) More scalable: bucket by normalized length + radix/counting sort inside buckets
# - If many numbers have the same length and lengths are large, comparison-based sorting becomes heavy: comparisons cost O(L) each.
# - For a bucket of m strings all length L, radix (LSD) sorting by digits takes O(m * L) time and O(m) extra memory; doing it for all buckets gives O(sum_m L_m * m) which is optimal in this model.
#
# Implementation (Python): stable radix/counting sort within each equal-length bucket. This returns original strings in numeric order and preserves duplicates; it stores normalized strings for comparison but returns the original strings.
#
# Code:
#
# from collections import defaultdict
#
# def _counting_sort_by_digit(arr, pos):
#     """Stable counting sort of arr (list of (normalized, original)) on normalized[pos] digit (0-9)."""
#     n = len(arr)
#     counts = [0] * 10
#     for nz, orig in arr:
#         digit = ord(nz[pos]) - 48  # '0' -> 48
#         counts[digit] += 1
#     # prefix sums -> positions
#     for i in range(1, 10):
#         counts[i] += counts[i-1]
#     out = [None] * n
#     # place in reverse order to keep stability
#     for nz, orig in reversed(arr):
#         digit = ord(nz[pos]) - 48
#         counts[digit] -= 1
#         out[counts[digit]] = (nz, orig)
#     return out
#
# def _radix_sort_equal_length(bucket):
#     """bucket is list of (normalized_string, original_string), all normalized same length."""
#     if not bucket:
#         return []
#     L = len(bucket[0][0])
#     arr = bucket
#     # LSD radix: sort from last digit to first
#     for pos in range(L-1, -1, -1):
#         arr = _counting_sort_by_digit(arr, pos)
#     # return list of original strings in numeric order
#     return [orig for (nz, orig) in arr]
#
# def sort_numeric_strings_radix(arr):
#     """
#     More scalable sort: bucket by normalized length, then radix-sort each bucket.
#     Returns original strings in ascending numeric order.
#     Memory: O(n) extra; Time: O(sum over buckets of (m * L)).
#     """
#     buckets = defaultdict(list)  # length -> list of (normalized, original)
#     for s in arr:
#         nz = s.lstrip('0')
#         if nz == "":
#             nz = "0"
#         buckets[len(nz)].append((nz, s))
#     # process lengths in increasing order
#     result = []
#     for length in sorted(buckets):
#         bucket = buckets[length]
#         if len(bucket) <= 1:
#             # nothing to sort
#             result.extend(orig for (_, orig) in bucket)
#         else:
#             result.extend(_radix_sort_equal_length(bucket))
#     return result
#
# When to use this:
# - Use when you may have many very long numbers of equal length and need better-than-comparison performance.
# - Time: O(total_digits) across all numbers (i.e., O(sum len(nz_i))) plus low-order overhead.
# - Memory: O(n) extra for temp arrays used during counting/radix passes.
# - Note: if L or n are extremely large (e.g., 1e6 × 1e6 digits), runtime will still be enormous — you need distributed/external approaches.
#
# 3) If the data do not fit in RAM: external (disk) sorting
# - Break input into chunks that fit in memory. For each chunk, normalize and sort in-memory (use above methods), write sorted chunk to disk.
# - Then do a K-way merge of chunk files using a min-heap. Each heap item needs current value from a file; comparison should be by (length, normalized_string). You can store normalized strings on disk and stream them, or stream original strings while normalizing on-the-fly for comparison (be careful to avoid repeated full scans — store normalized value in the chunk file).
# - This is standard external merge sort. Complexity: O(total_data * log k) disk I/O plus CPU for normalizing/comparing.
#
# Other practical notes and edge cases
# - Leading zeros: the algorithm uses normalization (strip leading zeros) to evaluate numeric value. "0", "00", "000" are all numeric zero.
# - Ties (equal numeric values): Unless you require a particular tie-break, any order among equal numeric values is acceptable. The implementations I gave are stable w.r.t. input order for equal keys.
# - Very large memory footprint if you copy normalized strings; the radix approach tries to avoid extra allocations during sorting by reusing arrays, but normalization still makes copies. If you want zero extra memory copies you need to implement comparisons that scan the original string skipping leading zeros — but that makes comparisons O(L) and is not better than the simple method; comparisons may be called many times if using Python's comparison-based sort.
# - If the environment has optimized C sorts and you can afford the memory/time, the simple key-based solution is concise and often good enough:
#   sorted(arr, key=lambda s: (len(s.lstrip('0') or '0'), s.lstrip('0') or '0'))
#
# Example
# Input: ["10", "2", "001", "0", "00012", "12"]
# Normalized values: [("10",10), ("2",2), ("001",1), ("0",0), ("00012",12), ("12",12)]
# Sorted numeric order -> ["0", "001", "2", "10", "00012", "12"]
#
# Summary recommendation
# - If n and sizes are moderate: use the simple key-based approach (easy, correct).
# - If many very long equal-length numbers or you need guaranteed O(total_digits) worst-case: use bucket-by-length + radix/counting inside each bucket.
# - If the dataset is larger than RAM: implement external merge sort (write sorted chunks, then k-way merge).
#
# If you want, I can:
# - Provide a memory-optimized comparator-based Python implementation that avoids creating normalized copies (at cost of slower comparisons).
# - Provide the external merge-sort scaffolding (read-chunk, sort-chunk, write, merge).
# - Provide working unit tests and benchmarks for small, medium, and large synthetic data. Which would you like next?

# %% [markdown]
# ### Reasoning

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "minimal"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# One well-known solution (farmer = F, wolf = W, goat = G, cabbage = C; sides: left → right):
#
# 1. Farmer takes goat across. (Left: W, C. Right: F, G)
# 2. Farmer returns alone. (Left: W, C. Right: G)
# 3. Farmer takes wolf across. (Left: C. Right: F, W, G)
# 4. Farmer brings goat back. (Left: G, C. Right: W)
# 5. Farmer takes cabbage across. (Left: G. Right: F, W, C)
# 6. Farmer returns alone. (Left: G. Right: W, C)
# 7. Farmer takes goat across. (Left: —. Right: F, W, G, C)
#
# All items safely on the far side.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "medium"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# Label the starting bank Left and the destination bank Right.
#
# 1. Farmer takes the goat from Left to Right. (Left: wolf, cabbage. Right: goat.)
# 2. Farmer returns alone from Right to Left. (Left: wolf, cabbage. Right: goat.)
# 3. Farmer takes the wolf from Left to Right. (Left: cabbage. Right: wolf, goat.)
# 4. Farmer brings the goat back from Right to Left. (Left: goat, cabbage. Right: wolf.)
# 5. Farmer takes the cabbage from Left to Right. (Left: goat. Right: wolf, cabbage.)
# 6. Farmer returns alone from Right to Left. (Left: goat. Right: wolf, cabbage.)
# 7. Farmer takes the goat from Left to Right. (Left: —. Right: wolf, goat, cabbage.)
#
# No step leaves wolf alone with goat or goat alone with cabbage. Total crossings: 7.

# %%
prompt = """
A farmer needs to cross a river with a wolf, a goat, and a cabbage. 
He can only carry one item with him at a time. If left alone, the wolf will eat the goat, 
and the goat will eat the cabbage. Write down the step-by-step sequence the farmer must follow 
to get everything safely across.
"""

response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort": "high"}, 
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
# Out:
# 1. Farmer takes the goat across. (Left: wolf, cabbage. Right: goat — safe.)
# 2. Farmer returns alone. (Left: farmer, wolf, cabbage. Right: goat.)
# 3. Farmer takes the wolf across. (Arrives with wolf where goat is.)
# 4. Farmer brings the goat back. (Left: farmer, goat, cabbage. Right: wolf — safe.)
# 5. Farmer takes the cabbage across. (Left: goat. Right: wolf, cabbage — safe.)
# 6. Farmer returns alone. (Left: farmer, goat. Right: wolf, cabbage.)
# 7. Farmer takes the goat across. (All across safely: wolf, goat, cabbage.)
#
# This avoids leaving wolf with goat or goat with cabbage unattended.

# %%
response = client.responses.create(
    model="gpt-5-mini",
    input="""
    Please use the code_exec tool to calculate the total number of unique vowels (a, e, i, o, u) in 
    the phrase "supercalifragilisticexpialidocious", then compute the factorial of that count.
    """,
    text={"format": {"type": "text"}},
    tools=[
        {
            "type": "custom",
            "name": "code_exec",
            "description": "Executes arbitrary python code",
        }
    ]
)
# Out:
# ResponseReasoningItem(id='rs_68b02b17f990819dbb3f87132ffd0bb70a42b420d98d7e73', summary=[], type='reasoning', content=None, encrypted_content=None, status=None)

# %%
print(response.output[1])
# Out:
# ResponseCustomToolCall(call_id='call_XrYXoql95IPUBqJzvLWryuCl', input='# Counting unique vowels in the given phrase and computing factorial of the count\ntext = "supercalifragilisticexpialidocious"\nvowels = set("aeiou")\nunique_vowels = sorted(list(vowels.intersection(set(text))))\ncount = len(unique_vowels)\n\nimport math\nfactorial_of_count = math.factorial(count)\n\n{\n    "text": text,\n    "unique_vowels": unique_vowels,\n    "count": count,\n    "factorial": factorial_of_count\n}', name='code_exec', type='custom_tool_call', id='ctc_68b02b1bff28819d9d429e820f832fb30a42b420d98d7e73', status='completed')

# %%
tool_call = response.output[1] if len(response.output) > 1 else None

if tool_call and tool_call.type == "custom_tool_call":
    print("--- tool name ---")
    print(tool_call.name)
    print("--- tool call argument (generated code) ---")
    print(tool_call.input)
# Out:
# --- tool name ---
# code_exec
# --- tool call argument (generated code) ---
# # Counting unique vowels in the given phrase and computing factorial of the count
# text = "supercalifragilisticexpialidocious"
# vowels = set("aeiou")
# unique_vowels = sorted(list(vowels.intersection(set(text))))
# count = len(unique_vowels)
#
# import math
# factorial_of_count = math.factorial(count)
#
# {
#     "text": text,
#     "unique_vowels": unique_vowels,
#     "count": count,
#     "factorial": factorial_of_count
# }
